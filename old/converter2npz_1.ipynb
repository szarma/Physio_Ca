# %%
### Preface
import javabridge
import bioformats as bf
javabridge.start_vm(class_path=bf.JARS)
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sys import path as syspath
syspath.append("./functions/")
from physio_def_1 import getApparentFreq, importFrames, getTimes

from plotFirst_1 import plotImage

from shutil import move as movecarefully

import os

# %%
from collections import OrderedDict

# %%
def do_single_Series(iSeries):
    from warnings import warn
    try:
        im = xml.image(iSeries)
        Name = im.Name

        if Nimages==1:
            npzFile   = filename.replace(extension,".npz")
            imageFile = filename.replace(extension,".png")
            dimFile   = filename.replace(extension,".txt")
        else:
            npzFile   = filename.replace(extension,f"_{iSeries}_{Name}.npz")
            imageFile = filename.replace(extension,f"_{iSeries}_{Name}.png")
            dimFile   = filename.replace(extension,f"_{iSeries}_{Name}.txt")

        npzFile   = os.path.join(newdir,npzFile   )
        imageFile = os.path.join(newdir,imageFile )
        dimFile   = os.path.join(newdir,dimFile   )

        dimensions = dict(zip("TXY",(getattr(im.Pixels, "Size"+dim) for dim in "TXY")))

        if dimensions["T"]>1:
            dimensions['freq'] = getApparentFreq(iSeries,xml)

        howManyFirstFrames = min(10,dimensions["T"])
        firstFrames = importFrames(rdr,idx=iSeries, which=(howManyFirstFrames,))

        extraDims = len(firstFrames.shape)>3
        if extraDims:
        #         print("There are more dimensions here than expected.\nI'll remedy this for now, but be shure to keep this in mind.")
            retainDims = np.where(firstFrames.std(axis=tuple(range(len(firstFrames.shape)-1)))>0)[0]
            assert len(retainDims)==1
            retainDims = int(retainDims[0])
            firstFrames = firstFrames.T[retainDims].T
        else:
            retainDims = None

        meanFirstFrames = firstFrames.mean(axis=0)
        #     stdFirstFrames = firstFrames.std(axis=0)

        pxSize = im.Pixels.get_PhysicalSizeX()
        pxUnit = im.Pixels.get_PhysicalSizeXUnit()
        text = "\n".join([" %s:%i"%(c,dimensions[c])  for c in "XYT"])
        if dimensions["T"]>1:
            text += "\n f:%.1f Hz"%dimensions['freq']
        dimensions["pxSize"] = pxSize
        dimensions["pxUnit"] = pxUnit
        pd.DataFrame([dimensions]).to_csv(dimFile, index=False)
        
        try:
            plotImage(meanFirstFrames.T,pxSize=pxSize,pxUnit=pxUnit,
                      savePath=imageFile,
                      addInfo=text)
            plt.close()
        except:
            pass

        time = getTimes(xml_=xml,idx_=iSeries)

        mintype = pd.to_numeric(firstFrames.flatten(),downcast="unsigned").dtype
        allimage = importFrames(
            rdr,
            idx=iSeries,
            dtype=mintype,
            which=(dimensions['T'],None,None,retainDims)[:3+int(extraDims)]
        #     which=(None,None,None)+tuple([retainDims][:int(extraDims)])
        )
        np.savez_compressed(npzFile,time=time,data=allimage)
        return 0
    except:
        warn(f"something was off doing {iSeries} in file {pathToRecord}.\nI'll continue, but with a note in the folder.")
        with open(os.path.join(newdir,filename.replace(extension,".err")),"a") as fw:
            fw.write(f"error for series number {iSeries}\n")
        return 1

# %%
def prepareOverview(directory):    
    overview = []
    for txtname in os.listdir(directory)[::-1]:
        if not txtname.endswith("txt"):
            continue
        try:
            sr = pd.read_csv(os.path.join(directory,txtname)).loc[0]
            sr = sr.append(pd.Series({
                "filename"    :    txtname.rstrip(".txt"),
                "iSeries"     :int(txtname.split("_")[-2]),
                "Series_Name" :    txtname.split("_")[-1],
            }))
        except:
            sr = pd.Series({"filename":txtname})
        overview += [sr]

    overview = pd.DataFrame(overview)
    overview.set_index("iSeries",inplace=True)
    overview.sort_index(inplace=True)

    overview.to_csv(os.path.join(directory,"overview.csv"))

# %%
# pd.read_excel('/Volumes/physio/team/slakrupnik/project/experiments/Sandra/2019_09_25/info.xlsx')

# %% [markdown]
# # If you want to parse a single record

# %%
# pathToRecord = '/Volumes/physio/team/slakrupnik/project/experiments/MB/Cytokines/cytokines-2.lif'
# pathToRecord = '/Volumes/physio/team/slakrupnik/project/experiments/Sandra/NIKON/2019_08_06/256x32_image_slice2_0la_2Ca.nd2'
pathToRecord = "/Volumes/physio/team/slakrupnik/project/experiments/Ya-Chi/Nov 6 2019.lif"

# %%
md = bf.get_omexml_metadata(pathToRecord)
xml = bf.OMEXML(md)
Nimages = xml.get_image_count()
rdr = bf.ImageReader(pathToRecord, perform_init=True)
pathToDir, filename = os.path.split(pathToRecord)
extension = "."+filename.split(".")[-1]
newdir = os.path.join(pathToDir,filename.rstrip(extension))

# %%
if not os.path.isdir(newdir):
    os.makedirs(newdir)

# %%
OrderedDict([(i,xml.image(i).Name) for i in range(Nimages)])
# Out:
# OrderedDict([(0, 'Image015'),
#              (1, 'Image016'),
#              (2, 'Image020'),
#              (3, 'Image021'),
#              (4, 'Image022'),
#              (5, 'Image028'),
#              (6, 'Image031'),
#              (7, 'Series038_6mM glucose'),
#              (8, 'Image051'),
#              (9, 'Series056_6mM glucose'),
#              (10, 'Image060'),
#              (11, 'Series062_8mM glucose'),
#              (12, 'Series063_8mM glucose'),
#              (13, 'Image080'),
#              (14, 'Series094'),
#              (15, 'Image095'),
#              (16, 'Series106_6mM glucose'),
#              (17, 'Image112'),
#              (18, 'Series113_8mM glucose')])

# %%
errd = 0
for iSeries in range(Nimages):
    errd += do_single_Series(iSeries)

if errd==0:
    movecarefully(pathToRecord,os.path.join(newdir,filename+"_done"))

if Nimages>1:
    prepareOverview(newdir)
# Out:
# /Users/srdjan/anaconda2/envs/physio/lib/python3.7/site-packages/ipykernel_launcher.py:71: UserWarning: something was off doing 0 in file /Volumes/physio/team/slakrupnik/project/experiments/Ya-Chi/Nov 6 2019.lif.
# I'll continue, but with a note in the folder.
# /Users/srdjan/anaconda2/envs/physio/lib/python3.7/site-packages/ipykernel_launcher.py:71: UserWarning: something was off doing 1 in file /Volumes/physio/team/slakrupnik/project/experiments/Ya-Chi/Nov 6 2019.lif.
# I'll continue, but with a note in the folder.
# /Users/srdjan/anaconda2/envs/physio/lib/python3.7/site-packages/ipykernel_launcher.py:71: UserWarning: something was off doing 4 in file /Volumes/physio/team/slakrupnik/project/experiments/Ya-Chi/Nov 6 2019.lif.
# I'll continue, but with a note in the folder.
# /Users/srdjan/anaconda2/envs/physio/lib/python3.7/site-packages/ipykernel_launcher.py:71: UserWarning: something was off doing 5 in file /Volumes/physio/team/slakrupnik/project/experiments/Ya-Chi/Nov 6 2019.lif.
# I'll continue, but with a note in the folder.
# /Users/srdjan/anaconda2/envs/physio/lib/python3.7/site-packages/ipykernel_launcher.py:71: UserWarning: something was off doing 6 in file /Volumes/physio/team/slakrupnik/project/experiments/Ya-Chi/Nov 6 2019.lif.
# I'll continue, but with a note in the folder.
# /Users/srdjan/anaconda2/envs/physio/lib/python3.7/site-packages/ipykernel_launcher.py:71: UserWarning: something was off doing 8 in file /Volumes/physio/team/slakrupnik/project/experiments/Ya-Chi/Nov 6 2019.lif.
# I'll continue, but with a note in the folder.
# /Users/srdjan/anaconda2/envs/physio/lib/python3.7/site-packages/ipykernel_launcher.py:71: UserWarning: something was off doing 10 in file /Volumes/physio/team/slakrupnik/project/experiments/Ya-Chi/Nov 6 2019.lif.
# I'll continue, but with a note in the folder.
# /Users/srdjan/anaconda2/envs/physio/lib/python3.7/site-packages/ipykernel_launcher.py:71: UserWarning: something was off doing 11 in file /Volumes/physio/team/slakrupnik/project/experiments/Ya-Chi/Nov 6 2019.lif.
# I'll continue, but with a note in the folder.
# /Users/srdjan/anaconda2/envs/physio/lib/python3.7/site-packages/ipykernel_launcher.py:71: UserWarning: something was off doing 13 in file /Volumes/physio/team/slakrupnik/project/experiments/Ya-Chi/Nov 6 2019.lif.
# I'll continue, but with a note in the folder.
# /Users/srdjan/anaconda2/envs/physio/lib/python3.7/site-packages/ipykernel_launcher.py:71: UserWarning: something was off doing 14 in file /Volumes/physio/team/slakrupnik/project/experiments/Ya-Chi/Nov 6 2019.lif.
# I'll continue, but with a note in the folder.
# /Users/srdjan/anaconda2/envs/physio/lib/python3.7/site-packages/ipykernel_launcher.py:71: UserWarning: something was off doing 15 in file /Volumes/physio/team/slakrupnik/project/experiments/Ya-Chi/Nov 6 2019.lif.
# I'll continue, but with a note in the folder.
# /Users/srdjan/anaconda2/envs/physio/lib/python3.7/site-packages/ipykernel_launcher.py:71: UserWarning: something was off doing 17 in file /Volumes/physio/team/slakrupnik/project/experiments/Ya-Chi/Nov 6 2019.lif.
# I'll continue, but with a note in the folder.

# %% [markdown]
# # If you want to parse all records within a directory

# %%
pathToFolder = '/Volumes/physio/team/slakrupnik/project/experiments/Sandra/NIKON/2019_08_06'

# %%
for filename in os.listdir(pathToFolder):
    if "slice3" not in filename: continue
    print (filename)
# Out:
# 256x32_image_slice3_0la_04Ca.nd2
# 256x32_image_slice3_0la_04Ca001.nd2
# 256x32_image_slice3_0la_10Ca.nd2
# 256x32_image_slice3_0la_2Ca.nd2
# 256x32_image_slice3_0la_2Ca001.nd2
# 256x32_image_slice3_0la_2Ca002.nd2
# 256x36_image_slice3_0la_2Ca.nd2
# 256x36_image_slice3_0la_2Ca001.nd2
# 256x36_image_slice3_0la_2Ca002.nd2
# 256x36_image_slice3_0la_2Ca003.nd2
# 512x512_image_slice3_16la_04Ca.nd2
# 512x512_image_slice3_16la_10Ca.nd2
# 512X512_image_slice3_16la_2ca.nd2
# 512x512_image_slice3_16la_2Ca001.nd2
# 512X512_image_slice3_16la_2ca.txt
# 512X512_image_slice3_16la_2ca.png
# 512X512_image_slice3_16la_2ca.npz

# %%
    pathToRecord = os.path.join(pathToFolder,filename)
    try:
        md = bf.get_omexml_metadata(pathToRecord)
    except:
        # if it is something else
        continue
    xml = bf.OMEXML(md)
    Nimages = xml.get_image_count()
    rdr = bf.ImageReader(pathToRecord, perform_init=True)
    pathToDir, filename = os.path.split(pathToRecord)
    extension = "."+filename.split(".")[-1]
    newdir = os.path.join(pathToDir,filename.rstrip(extension))

    if not os.path.isdir(newdir):
        os.makedirs(newdir)

    errd = 0
    for iSeries in range(Nimages):
        errd += do_single_Series(iSeries)

    if errd==0:
        movecarefully(pathToRecord,os.path.join(newdir,filename+"_done"))

    if Nimages>1:
        prepareOverview(newdir)

# %% [markdown]
# # Only overview [Leica]

# %%
pathToDir = "/Volumes/physio/team/slakrupnik/project/experiments/Sandra/2019_10_15/Experiment38b/"

# %%
prepareOverview(pathToDir)

# %%
df = pd.read_csv(pathToDir+"overview.csv")

# %%
df
# Out:
#     iSeries  Unnamed: 0       T     X     Y       freq    pxSize pxUnit  \
# 0         0           0       1  1024  1024        NaN  0.240352     µm
# 1         1           0       1  1024  1024        NaN  0.258162     µm
# 2         2           0       1  1024  1024        NaN  0.258162     µm
# 3         3           0       1  1024  1024        NaN  0.312712     µm
# 4         4           0   94027   128    64  99.042816  2.518935     µm
# 5         5           0       1  1024  1024        NaN  0.240746     µm
# 6         6           0       1  1024  1024        NaN  0.257745     µm
# 7         7           0   86082   128    64  99.049445  2.076169     µm
# 8         8           0       1  1024  1024        NaN  0.239184     µm
# 9         9           0       1  1024  1024        NaN  0.424412     µm
# 10       10           0   14968   256   256   9.901567  1.702641     µm
# 11       11           0   25488   128   128  84.267360  3.418688     µm
# 12       12           0   14972   256   256   9.902051  1.702641     µm
# 13       13           0   25895   128   128  84.273357  3.418688     µm
# 14       14           0   16199   256   256   9.902231  1.702641     µm
# 15       15           0   25619   128   128  84.275004  3.418688     µm
# 16       16           0       1   512   512        NaN  0.849654     µm
# 17       17           0       1   128    64        NaN  3.418688     µm
# 18       18           0   96972   128    64  99.023156  3.418688     µm
# 19       19           0       1  1024  1024        NaN  0.424412     µm
# 20       20           0  107962   128   128  84.273689  3.418688     µm
# 21       21           0       1  1024  1024        NaN  0.240352     µm
# 22       22           0     101   128   128  84.317109  1.936065     µm
# 23       23           0   79967   128   128  84.304655  1.936065     µm
#
#                       filename    Series_Name
# 0     Experiment38b_0_Image003   Image003.txt
# 1     Experiment38b_1_Image003   Image003.txt
# 2     Experiment38b_2_Image010   Image010.txt
# 3     Experiment38b_3_Image011   Image011.txt
# 4     Experiment38b_4_Image013   Image013.txt
# 5    Experiment38b_5_Series014  Series014.txt
# 6     Experiment38b_6_Image021   Image021.txt
# 7     Experiment38b_7_Image023   Image023.txt
# 8    Experiment38b_8_Series024  Series024.txt
# 9     Experiment38b_9_Image030   Image030.txt
# 10   Experiment38b_10_Image040   Image040.txt
# 11  Experiment38b_11_Series041  Series041.txt
# 12  Experiment38b_12_Series042  Series042.txt
# 13  Experiment38b_13_Series043  Series043.txt
# 14  Experiment38b_14_Series044  Series044.txt
# 15  Experiment38b_15_Series045  Series045.txt
# 16  Experiment38b_16_Series046  Series046.txt
# 17   Experiment38b_17_Image049   Image049.txt
# 18   Experiment38b_18_Image050   Image050.txt
# 19  Experiment38b_19_Series051  Series051.txt
# 20   Experiment38b_20_Image053   Image053.txt
# 21  Experiment38b_21_Series054  Series054.txt
# 22   Experiment38b_22_Image059   Image059.txt
# 23  Experiment38b_23_Series060  Series060.txt

# %%
df.query("freq>.6")
# Out:
#     iSeries  Unnamed: 0     T    X    Y    pxSize pxUnit  \
# 10       10           0  4889  512  512  0.531302     µm
# 13       13           0  2386  512  512  0.531302     µm
# 16       16           0  3658  512  512  0.348258     µm
# 19       19           0  1420  512  512  0.348258     µm
# 22       22           0  4745  512  512  0.478835     µm
#
#                               filename    Series_Name      freq
# 10  Pancreas islet OGB 56_10_Series016  Series016.txt  1.000204
# 13  Pancreas islet OGB 56_13_Series020  Series020.txt  1.000419
# 16  Pancreas islet OGB 56_16_Series025  Series025.txt  1.000273
# 19  Pancreas islet OGB 56_19_Series029  Series029.txt  1.000705
# 22  Pancreas islet OGB 56_22_Series033  Series033.txt  1.000210

# %% [markdown]
# # Only overview [Nikon]

# %%
df = []
for folderName in ["2019_09_25", "2019_08_06"]:
    pathToDir = "/Volumes/physio/team/slakrupnik/project/experiments/Sandra/NIKON/%s/"%folderName
    allFiles = sorted([fn for fn in os.listdir(pathToDir) if fn.endswith(".nd2")])

    for fn in allFiles:
        tentDir = pathToDir+fn.rstrip(".nd2")+"/"
        if os.path.isdir(tentDir):
            tmp = pd.read_csv(tentDir+fn.replace("nd2","txt")).loc[0]
            tmp = tmp.append(pd.Series({"filename":fn.rstrip(".nd2"),"folder":folderName}))
            df += [tmp]

# %%
df = pd.DataFrame(df)

# %%
df['Tmax'] = df["T"]/df["freq"]

# %%
df.sort_values("Tmax", ascending=False)
# Out:
#         T    X    Y        freq    pxSize pxUnit  \
# 30   3330  512  512    1.928090  0.415082     µm
# 28   2175  512  512    1.928107  0.415082     µm
# 4   99059  256   64  101.066012  1.245245     µm
# 27   1808  512  512    1.928667  0.138107     µm
# 29   1430  512  512    1.928000  0.415082     µm
# 0   64453  256   64  173.340006  1.245245     µm
# 26    714  512  512    1.928200  0.138107     µm
# 5   63156  256   64  183.203193  1.660326     µm
# 7   60151  256   64  206.325159  1.660326     µm
# 25    481  512  512    1.926945  0.622622     µm
# 6   56345  256   64  225.859529  1.660326     µm
# 1    2920  256  256   15.232434  1.245245     µm
# 3   40698  256   64  225.358737  1.245245     µm
# 16  55486  256   32  439.082381  0.830163     µm
# 18  49450  256   32  439.006098  0.830163     µm
# 33    194  512  512    1.926165  0.622622     µm
# 17  42436  256   32  438.967555  0.830163     µm
# 2    1409  256  256   15.223393  1.245245     µm
# 10  37614  256   32  438.982194  0.414320     µm
# 12  37302  256   32  438.963175  0.414320     µm
# 19  34386  256   32  438.877631  0.830163     µm
# 24  33572  256   32  438.841668  0.830163     µm
# 8   31044  256   32  438.922333  0.414320     µm
# 15  29157  256   32  438.750918  0.830163     µm
# 9   28572  256   32  438.848472  0.414320     µm
# 11  28175  256   32  438.738708  0.414320     µm
# 20  27205  256   32  438.709318  0.830163     µm
# 14  27055  256   32  438.754738  0.276214     µm
# 21  25604  256   32  438.585296  0.830163     µm
# 22  21323  256   32  438.501530  0.830163     µm
# 23  10460  256   32  437.633802  0.830163     µm
# 13      1  256   32         NaN  0.414320     µm
# 31      1  512  512         NaN  0.622622     µm
# 32      1  512  512         NaN  0.622622     µm
# 34      1  512  512         NaN  0.622622     µm
#
#                                     filename      folder         Tmax
# 30          512x512_image_slice3_16la_2Ca001  2019_08_06  1727.098039
# 28            512x512_image_slice3_16la_04Ca  2019_08_06  1128.049195
# 4   Slice1_Glu6_TEA_2Ca_Diazoxide_512x64_003  2019_09_25   980.141576
# 27                 512x512_image_slice1_16la  2019_08_06   937.435151
# 29            512x512_image_slice3_16la_10Ca  2019_08_06   741.701127
# 0                       Slice1_Glu6_Ryn100nM  2019_09_25   371.829918
# 26           512x512__image_slice1_16la_10Ca  2019_08_06   370.293511
# 5                            Slice2_Glu8_007  2019_09_25   344.731983
# 7                            Slice2_Glu8_010  2019_09_25   291.534974
# 25             512X512_image_slice3_16la_2ca  2019_08_06   249.617884
# 6                            Slice2_Glu8_008  2019_09_25   249.469218
# 1           Slice1_Glu6_Ryn100nM_512x512_001  2019_09_25   191.696222
# 3            Slice1_Glu6_TEA_2Ca_512x512_006  2019_09_25   180.592066
# 16           256x32_image_slice3_0la_04Ca001  2019_08_06   126.368086
# 18               256x32_image_slice3_0la_2Ca  2019_08_06   112.640804
# 33                                  TEA_SLOW  2019_08_06   100.718289
# 17              256x32_image_slice3_0la_10Ca  2019_08_06    96.672293
# 2             Slice1_Glu6_TEA_2Ca_512x512_00  2019_09_25    92.554928
# 10              256x32_image_slice1_0la_10Ca  2019_08_06    85.684569
# 12            256x32_image_slice1_0la_10Ca00  2019_08_06    84.977515
# 19            256x32_image_slice3_0la_2Ca001  2019_08_06    78.349858
# 24            256x36_image_slice3_0la_2Ca003  2019_08_06    76.501395
# 8                    256x32_image_slice1_0la  2019_08_06    70.727775
# 15              256x32_image_slice3_0la_04Ca  2019_08_06    66.454562
# 9               256x32_image_slice1_0la_04Ca  2019_08_06    65.106755
# 11           256x32_image_slice1_0la_10Ca001  2019_08_06    64.218177
# 20             256x32_image_slice3_0la_2Ca00  2019_08_06    62.011448
# 14            256x32_image_slice2_0la_2Ca001  2019_08_06    61.663152
# 21               256x36_image_slice3_0la_2Ca  2019_08_06    58.378610
# 22            256x36_image_slice3_0la_2Ca001  2019_08_06    48.626968
# 23             256x36_image_slice3_0la_2Ca00  2019_08_06    23.901262
# 13                  256x32_image_slice1_64la  2019_08_06          NaN
# 31                                    Slice3  2019_08_06          NaN
# 32                    TEASLOWRECORDING_image  2019_08_06          NaN
# 34                                     slice  2019_08_06          NaN
