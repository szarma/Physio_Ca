# %% [markdown]
# # Preambule

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import numpy as np

# %%
from sys import path as syspath
from os.path import expanduser
syspath.append(expanduser("~/Seafile/functions/"))

# %%
from general_functions import autocorr, tally

# %%
import scipy.io

# %%
mat = scipy.io.loadmat('./data/data.mat')

# %%
mat.keys()
# Out:
# dict_keys(['__header__', '__version__', '__globals__', 'data'])

# %%
len(mat["data"])
# Out:
# 1

# %%
len(mat["data"][0])
# Out:
# 23874

# %%
image = mat["data"][0]

# %%
tally(map(len,image))
# Out:
# [(1, 1), (256, 23873)]

# %%
image[-1].shape
# Out:
# (1, 1)

# %%
image = np.stack(image[:-1])

# %%
lastImage = mat["data"][0][-1]

# %% [markdown]
# # what is contained in this last image?

# %%
lastImage.shape
# Out:
# (1, 1)

# %%
lastImage = lastImage[0][0]

# %%
len(lastImage)
# Out:
# 2

# %%
lastImage[0].shape, lastImage[1].shape
# Out:
# ((500, 200, 3), (500, 200))

# %%
plt.imshow(lastImage[0].T[0])

# %%
plt.imshow(lastImage[0].T[1])

# %%
plt.imshow(lastImage[0].T[2])

# %%
plt.imshow(lastImage[1].T)

# %% [markdown]
# # Real data is in the image

# %%
image.shape
# Out:
# (23873, 256, 256)

# %%
x = np.random.choice(image.flatten(),10000)

# %%
plt.bar(*np.array(tally(x)).T)
plt.xlim(-1,70.5)
# Out:
# (-1, 70.5)
