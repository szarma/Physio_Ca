# %%
import os
from sys import path as syspath
syspath.append(os.path.expanduser("~/srdjan_functs/"))
# autoreload setup
# %load_ext autoreload
# %autoreload 1
# %aimport physio_def_2, Automatic1, Regions1, numeric

import javabridge
from bioformats import JARS as bfJARS
javabridge.start_vm(class_path=bfJARS, max_heap_size="6G")

import numpy as np
from Regions1 import Regions
from caiman import movie as cmovie
# merge obvious ROIs
from Regions1 import getPeak2BoundaryDF, getGraph_of_ROIs_to_Merge, mergeBasedOnGraph
import matplotlib.pyplot as plt
import pickle
from Automatic1 import saveRois
from physio_def_2 import Recording
# Out:
# /opt/tljh/user/envs/physio/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning:
#
# The sklearn.decomposition.incremental_pca module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.decomposition. Anything that cannot be imported from sklearn.decomposition is now part of the private API.

# %%
from pandas import Timedelta

# %%
# folder = "local_data/prototype/"
folder = "local_data/Sandra/2020_06_18/"

# %%
def get_filterSizes(px):
    base = int(np.ceil(6/px))
    wider = int(np.ceil(base*1.1))
    if wider==base: wider += 1
    toComb = int(np.ceil(base*1.3))
    if toComb <= wider: toComb += 1
    return [(base,), (wider,), (base,wider), (base,toComb)]

# %% [markdown]
# ### Process Lifs

# %%
lifs = [f for f in os.listdir(folder) if f.endswith("lif") and f[0]!="."]
lifs = sorted(lifs)
lifs
# Out:
# ['Experiment54a.lif',
#  'Experiment54b.lif',
#  'Experiment54c.lif',
#  'Experiment54d.lif',
#  'Experiment54e.lif']

# %%
# for exp in lifs:
#     rec = Recording(os.path.join(folder,exp))
#     rec.parse_metadata()
#     rec.save_metadata()

# %%
for exp in lifs:
    print (exp)
    rec = Recording(os.path.join(folder,exp))
    toDrop = [i for i,row in rec.metadata.iterrows() if "Series" not in row["Name"]]
    rec.metadata.drop(index=toDrop, inplace=True)
    if len(rec.metadata)>1:
        rec.calc_gaps()
        ff = np.any(
                [rec.metadata["gap"]>Timedelta("5s")]+
                [rec.metadata[c].diff().abs()>0 for c in ["pxSize", "SizeX", "SizeY"]],
            axis=0)
        sers = np.split(rec.metadata.Name.values, np.where(ff)[0])
    else:
        sers = [rec.metadata.Name.values]
    for serlist in sers:
        if len(serlist)==len(rec.metadata):
            ser="all"
        else:
            serrange = [int(el.replace("Series","")) for el in serlist]
            if len(serrange)>1:
                ser = "Series%03i-%i"%(serrange[0],serrange[-1])
            else:
                ser = "Series%03i"%(serrange[0])
        print("\t", ser, end="\t")
        saveDir = os.path.join(rec.folder, rec.Experiment+"_analysis", ser)
#         if os.path.isdir(saveDir):
#             donePickles = [(p,"%.1f"%(os.path.getsize(os.path.join(saveDir,p))/1e6)) \
#                            for p in os.listdir(saveDir) \
#                            if p.endswith("pkl") \
#                            and os.path.getsize(os.path.join(saveDir,p))>20e6
#                           ]
# #             donePickles = []
#             if len(donePickles)>=4:
#                 print(donePickles, "....done")
#                 continue
        print ("Need to work on ", saveDir)
        
        
        try:
            rec.import_series(ser)
        except:
            print (f"could not import {ser}")
            continue
        metadata = rec.Series[ser]["metadata"]
        filtSizes = get_filterSizes(metadata.pxSize)
        movie = cmovie(rec.Series[ser]["data"],fr=metadata["Frequency"])
        # break
        regions = Regions(movie, full=False, diag=True, debleach=False)

        for spFilt in filtSizes:
            pickleFile = os.path.join(saveDir, ".".join(map(str,spFilt))+"_rois.pkl")
            if os.path.isfile(pickleFile) and os.path.getsize(pickleFile)>100:
                continue
            else:
                print ("processing with filter size of ", spFilt)
            regions.constructRois(gSig_filt=spFilt)
            regions.update()
            while True:
                peak2bnd = getPeak2BoundaryDF(regions.df)
                df = peak2bnd.query("dist<1.")[["i","j"]]
                if len(df)==0: break
                gRois = getGraph_of_ROIs_to_Merge(df,regions,plot=False)
                dropped = mergeBasedOnGraph(gRois,regions)
                if dropped == 0: break

            regions.purge_lones((min(spFilt)*.5)**2)
            regions.sortFromCenter()
            saveRois(regions, saveDir, filename= ".".join(map(str,spFilt)), add_date=False, formats=["vienna"])
            assert hasattr(regions, "movie")
        del rec.Series[ser], regions, movie
    print ("")
# Out:
# Experiment54a.lif
# Recording not yet preprocessed. Preprocessing takes a few seconds and will speed up the usage later... Finished.
# 	 Series003	Need to work on  local_data/Sandra/2020_06_18/Experiment54a.lif_analysis/Series003
# processing with filter size of  (8,)
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 764 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 20 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 2 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 0 subsumed into existing ROIs.
# deleted 60 rois. 237 remain.
# vienna
# processing with filter size of  (9,)
# more than two attractors, not implemented yet, will skip
# 673 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 18 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 1 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 0 subsumed into existing ROIs.
# deleted 68 rois. 199 remain.
# vienna
# processing with filter size of  (8, 9)
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 499 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 11 subsumed into existing ROIs.
# 8 subsumed into existing ROIs.
# deleted 44 rois. 201 remain.
# vienna
# processing with filter size of  (8, 11)
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 686 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 20 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 10 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 0 subsumed into existing ROIs.
# deleted 53 rois. 205 remain.
# vienna
# 	 Series004	Need to work on  local_data/Sandra/2020_06_18/Experiment54a.lif_analysis/Series004
# processing with filter size of  (4,)
# 115 subsumed into existing ROIs.
# 2 subsumed into existing ROIs.
# deleted 7 rois. 156 remain.
# vienna
# processing with filter size of  (5,)
# 99 subsumed into existing ROIs.
# 1 subsumed into existing ROIs.
# deleted 3 rois. 129 remain.
# vienna
# processing with filter size of  (4, 5)
# 81 subsumed into existing ROIs.
# 4 subsumed into existing ROIs.
# deleted 7 rois. 139 remain.
# vienna
# processing with filter size of  (4, 6)
# 97 subsumed into existing ROIs.
# 3 subsumed into existing ROIs.
# deleted 7 rois. 112 remain.
# vienna
#
# Experiment54b.lif
# Recording not yet preprocessed. Preprocessing takes a few seconds and will speed up the usage later... Finished.
# 	 all	Need to work on  local_data/Sandra/2020_06_18/Experiment54b.lif_analysis/all
# processing with filter size of  (7,)
# more than two attractors, not implemented yet, will skip
# 699 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 11 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 0 subsumed into existing ROIs.
# deleted 57 rois. 887 remain.
# vienna
# processing with filter size of  (8,)
# 488 subsumed into existing ROIs.
# 3 subsumed into existing ROIs.
# deleted 34 rois. 696 remain.
# vienna
# processing with filter size of  (7, 8)
# more than two attractors, not implemented yet, will skip
# 493 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 7 subsumed into existing ROIs.
# 4 subsumed into existing ROIs.
# deleted 58 rois. 758 remain.
# vienna
# processing with filter size of  (7, 10)
# more than two attractors, not implemented yet, will skip
# 623 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 10 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 2 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 0 subsumed into existing ROIs.
# deleted 56 rois. 705 remain.
# vienna
#
# Experiment54c.lif
# Recording not yet preprocessed. Preprocessing takes a few seconds and will speed up the usage later... Finished.
# 	 Series001	Need to work on  local_data/Sandra/2020_06_18/Experiment54c.lif_analysis/Series001
# processing with filter size of  (4,)
# 612 subsumed into existing ROIs.
# 17 subsumed into existing ROIs.
# deleted 14 rois. 575 remain.
# vienna
# processing with filter size of  (5,)
# more than two attractors, not implemented yet, will skip
# 471 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 13 subsumed into existing ROIs.
# 2 subsumed into existing ROIs.
# deleted 18 rois. 462 remain.
# vienna
# processing with filter size of  (4, 5)
# 413 subsumed into existing ROIs.
# 15 subsumed into existing ROIs.
# deleted 13 rois. 512 remain.
# vienna
# processing with filter size of  (4, 6)
# 451 subsumed into existing ROIs.
# 8 subsumed into existing ROIs.
# deleted 14 rois. 415 remain.
# vienna
# 	 Series002-5	Need to work on  local_data/Sandra/2020_06_18/Experiment54c.lif_analysis/Series002-5
# processing with filter size of  (6,)
# deleted 7 rois. 277 remain.
# vienna
# processing with filter size of  (7,)
# 133 subsumed into existing ROIs.
# 1 subsumed into existing ROIs.
# deleted 9 rois. 237 remain.
# vienna
# processing with filter size of  (6, 7)
# 105 subsumed into existing ROIs.
# 5 subsumed into existing ROIs.
# deleted 6 rois. 256 remain.
# vienna
# processing with filter size of  (6, 8)
# 118 subsumed into existing ROIs.
# 4 subsumed into existing ROIs.
# deleted 8 rois. 223 remain.
# vienna
#
# Experiment54d.lif
# Recording not yet preprocessed. Preprocessing takes a few seconds and will speed up the usage later... Finished.
# 	 Series001	Need to work on  local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series001
# processing with filter size of  (4,)
# more than two attractors, not implemented yet, will skip
# 302 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 11 subsumed into existing ROIs.
# 5 subsumed into existing ROIs.
# deleted 70 rois. 172 remain.
# vienna
# processing with filter size of  (5,)
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 277 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 4 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 8 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 2 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 0 subsumed into existing ROIs.
# deleted 74 rois. 144 remain.
# vienna
# processing with filter size of  (4, 5)
# more than two attractors, not implemented yet, will skip
# 212 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 2 subsumed into existing ROIs.
# 3 subsumed into existing ROIs.
# deleted 49 rois. 163 remain.
# vienna
# processing with filter size of  (4, 6)
# 343 subsumed into existing ROIs.
# 12 subsumed into existing ROIs.
# deleted 71 rois. 142 remain.
# vienna
# 	 Series002	Need to work on  local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series002
# processing with filter size of  (4,)
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 454 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 12 subsumed into existing ROIs.
# 36 subsumed into existing ROIs.
# 1 subsumed into existing ROIs.
# deleted 88 rois. 194 remain.
# vienna
# processing with filter size of  (5,)
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 446 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 24 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 16 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 1 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 0 subsumed into existing ROIs.
# deleted 91 rois. 151 remain.
# vienna
# processing with filter size of  (4, 5)
# 338 subsumed into existing ROIs.
# 10 subsumed into existing ROIs.
# deleted 46 rois. 176 remain.
# vienna
# processing with filter size of  (4, 6)
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 531 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 14 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 10 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 0 subsumed into existing ROIs.
# deleted 68 rois. 168 remain.
# vienna
# 	 Series003	Need to work on  local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series003
# processing with filter size of  (4,)
# more than two attractors, not implemented yet, will skip
# 288 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 3 subsumed into existing ROIs.
# 10 subsumed into existing ROIs.
# 1 subsumed into existing ROIs.
# deleted 53 rois. 171 remain.
# vienna
# processing with filter size of  (5,)
# 244 subsumed into existing ROIs.
# 7 subsumed into existing ROIs.
# deleted 42 rois. 132 remain.
# vienna
# processing with filter size of  (4, 5)
# 217 subsumed into existing ROIs.
# 7 subsumed into existing ROIs.
# deleted 26 rois. 160 remain.
# vienna
# processing with filter size of  (4, 6)
# 311 subsumed into existing ROIs.
# 9 subsumed into existing ROIs.
# 1 subsumed into existing ROIs.
# deleted 36 rois. 132 remain.
# vienna
# 	 Series004	Need to work on  local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series004
# processing with filter size of  (4,)
# 225 subsumed into existing ROIs.
# 5 subsumed into existing ROIs.
# deleted 56 rois. 150 remain.
# vienna
# processing with filter size of  (5,)
# 196 subsumed into existing ROIs.
# 4 subsumed into existing ROIs.
# deleted 35 rois. 123 remain.
# vienna
# processing with filter size of  (4, 5)
# 156 subsumed into existing ROIs.
# 3 subsumed into existing ROIs.
# deleted 38 rois. 141 remain.
# vienna
# processing with filter size of  (4, 6)
# 228 subsumed into existing ROIs.
# 8 subsumed into existing ROIs.
# deleted 56 rois. 124 remain.
# vienna
#
# Experiment54e.lif
# Recording not yet preprocessed. Preprocessing takes a few seconds and will speed up the usage later... Finished.
# 	 Series001	Need to work on  local_data/Sandra/2020_06_18/Experiment54e.lif_analysis/Series001
# processing with filter size of  (4,)
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 490 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 18 subsumed into existing ROIs.
# 6 subsumed into existing ROIs.
# deleted 64 rois. 189 remain.
# vienna
# processing with filter size of  (5,)
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 447 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 15 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 0 subsumed into existing ROIs.
# deleted 78 rois. 150 remain.
# vienna
# processing with filter size of  (4, 5)
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 303 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 5 subsumed into existing ROIs.
# 9 subsumed into existing ROIs.
# deleted 50 rois. 177 remain.
# vienna
# processing with filter size of  (4, 6)
# more than two attractors, not implemented yet, will skip
# 477 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 17 subsumed into existing ROIs.
# 9 subsumed into existing ROIs.
# deleted 52 rois. 141 remain.
# vienna
# 	 Series002	Need to work on  local_data/Sandra/2020_06_18/Experiment54e.lif_analysis/Series002
# processing with filter size of  (4,)
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 468 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 12 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 5 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 1 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 0 subsumed into existing ROIs.
# deleted 88 rois. 199 remain.
# vienna
# processing with filter size of  (5,)
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 408 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# more than two attractors, not implemented yet, will skip
# 11 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 6 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 0 subsumed into existing ROIs.
# deleted 93 rois. 153 remain.
# vienna
# processing with filter size of  (4, 5)
# more than two attractors, not implemented yet, will skip
# 327 subsumed into existing ROIs.
# 14 subsumed into existing ROIs.
# deleted 54 rois. 176 remain.
# vienna
# processing with filter size of  (4, 6)
# more than two attractors, not implemented yet, will skip
# 513 subsumed into existing ROIs.
# more than two attractors, not implemented yet, will skip
# 15 subsumed into existing ROIs.
# 2 subsumed into existing ROIs.
# deleted 69 rois. 152 remain.
# vienna

# %% [markdown]
# ### Add images

# %%
toBreak = False
for cur,dirs,files in os.walk(folder):
    for file in files:
        if file.endswith('pkl') and "meta" not in file:
            path = os.path.join(cur,file)
            assert os.path.isfile(path)
            imageFile = os.path.join(cur, ".image_"+file.replace("_rois.pkl",".png"))
            if os.path.isfile(imageFile):
                continue
            print (path)
            with open(path,'rb') as f:
                regions = pickle.load(f)
            regions.update()
            im = regions.image
            figsize=np.array(im.shape)[::-1]/40
            fig = plt.figure(figsize=figsize)
            ax = fig.add_axes([0, 0, 1, 1])
            regions.plotEdges(ax=ax,color="red")
            fig.savefig(imageFile)
            plt.close(fig)
            toBreak = False
    if toBreak: break
# Out:
# local_data/Sandra/2020_06_18/Experiment54e.lif_analysis/Series002/4.6_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54e.lif_analysis/Series002/5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54e.lif_analysis/Series002/4_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54e.lif_analysis/Series002/4.5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54e.lif_analysis/Series001/4.6_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54e.lif_analysis/Series001/5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54e.lif_analysis/Series001/4_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54e.lif_analysis/Series001/4.5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series004/4.6_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series004/5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series004/4_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series004/4.5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series002/4.6_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series002/5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series002/4_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series002/4.5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series003/4.6_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series003/5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series003/4_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series003/4.5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series001/4.6_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series001/5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series001/4_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54d.lif_analysis/Series001/4.5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54b.lif_analysis/all/8_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54b.lif_analysis/all/7.10_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54b.lif_analysis/all/7_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54b.lif_analysis/all/7.8_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54c.lif_analysis/Series002-5/6.7_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54c.lif_analysis/Series002-5/6.8_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54c.lif_analysis/Series002-5/6_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54c.lif_analysis/Series002-5/7_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54c.lif_analysis/Series001/4.6_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54c.lif_analysis/Series001/5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54c.lif_analysis/Series001/4_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54c.lif_analysis/Series001/4.5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54a.lif_analysis/Series004/4.6_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54a.lif_analysis/Series004/5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54a.lif_analysis/Series004/4_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54a.lif_analysis/Series004/4.5_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54a.lif_analysis/Series003/8.9_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54a.lif_analysis/Series003/9_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54a.lif_analysis/Series003/8_rois.pkl
# local_data/Sandra/2020_06_18/Experiment54a.lif_analysis/Series003/8.11_rois.pkl

# %% [markdown]
# ### Power spectra

# %%
from numeric import power_spectrum

# %%
folder = "local_data/prototype/"

# %%
pw = []
for cur,dirs,files in os.walk(folder):
    for file in files:
        if file.endswith('lif'):
            path = os.path.join(cur,file)
            rec = Recording(path)
            toDrop = [i for i,row in rec.metadata.iterrows() if "Series" not in row["Name"]]
            rec.metadata.drop(index=toDrop, inplace=True)
            ser = rec.metadata.Name.iloc[0]
            rec.import_series(ser)
            data = rec.Series[ser]["data"]
            meanImage = data.mean(0)
            metadata = rec.Series[ser]["metadata"]
            regions = Regions(meanImage, gSig_filt=(max(2,int(4/metadata.pxSize)),))
            freq = metadata["Frequency"]
            x = np.vstack([ data[:,p[0],p[1]] for p in regions.df.peak])
            f,p = power_spectrum(x, fr=freq)
            metadata["f"] = f
            metadata["p"] = p
            metadata["exp"] = file
            pw += [metadata]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-1a3f10b6f441> in <module>
#       8             rec.metadata.drop(index=toDrop, inplace=True)
#       9             ser = rec.metadata.Name.iloc[0]
# ---> 10             rec.import_series(ser)
#      11             data = rec.Series[ser]["data"]
#      12             meanImage = data.mean(0)
#
# ~/srdjan_functs/physio_def_2.py in import_series(self, Series)
#     136             offset = metadata.loc[:i-1,"SizeT"].sum()
#     137             for t in range(metadata.loc[i,"SizeT"]):
# --> 138                 data[t+offset] = self.rdr.read(series=i, rescale=False, t=t)
#     139         self.Series[Series]["data"] = data
#     140
#
# ValueError: could not broadcast input array from shape (64,128) into shape (128,64)

# %%
import pandas as pd

# %%
pd.DataFrame(pw)
# Out:
#         Name   SizeT  SizeX  SizeY  pxSize pxUnit bit depth  Frequency  \
# 0  Series009  128000    128    128   1.540     µm     uint8      84.20
# 1  Series009  128000    128    128   2.040     µm     uint8      84.20
# 1  Series003     342    512    512   0.538     µm     uint8       0.47
# 0  Series002   11782    256    256   1.210     µm     uint8       9.89
# 0  Series001   32000    256    256   1.220     µm     uint8      50.00
# 0  Series003  128000    128    128   1.530     µm     uint8      84.10
# 0  Series001   32000    256    256   1.210     µm     uint8      50.10
# 0  Series001  128000    128    128   2.020     µm     uint8      84.20
# 0  Series010  128000    128    128   1.530     µm     uint8      84.20
# 2  Series012   84156    128    128   2.020     µm     uint8      84.20
# 1  Series004    8000    512    512   0.910     µm     uint8       9.89
# 0  Series009   32000    256    256   1.240     µm     uint8      50.10
# 0  Series002   32000    256    256   1.010     µm     uint8      50.10
# 1  Series003     988    512    512   0.482     µm     uint8       1.98
# 0  Series002   32000    256    256   1.010     µm     uint8      50.10
# 0  Series008   30040    256    256   0.868     µm     uint8      19.80
# 0  Series005   19351    256    256   1.820     µm     uint8       4.94
# 0  Series006   27360    256    256   0.895     µm     uint8      19.80
# 0  Series002   29223    128    128   1.540     µm     uint8      19.80
# 2  Series008  128000    128    128   2.030     µm     uint8      84.20
# 3  Series015  128000    128    128   2.040     µm     uint8      84.20
# 0  Series001   32000    256    256   0.922     µm     uint8      19.80
# 0  Series001   29699    256    256   1.340     µm     uint8       9.89
# 0  Series004   26651    256    256   0.931     µm     uint8      19.80
# 0  Series002   10720    256    256   1.820     µm     uint8       9.88
#
#            Start time                      End time        Duration  \
# 0 2020-05-18 11:40:41 2020-05-18 12:06:01.802881639 00:25:20.802881
# 1 2019-10-16 11:37:40 2019-10-16 12:03:00.128876586 00:25:20.128876
# 1 2015-11-16 11:47:12 2015-11-16 11:59:19.192293240 00:12:07.192293
# 0 2020-06-17 16:53:57 2020-06-17 17:13:48.404120199 00:19:51.404120
# 0 2020-05-27 13:18:51 2020-05-27 13:29:30.390981258 00:10:39.390981
# 0 2020-05-27 10:50:04 2020-05-27 11:15:25.234884220 00:25:21.234884
# 0 2020-05-18 17:25:06 2020-05-18 17:35:45.305979517 00:10:39.305979
# 0 2019-10-16 15:08:24 2019-10-16 15:33:44.317877239 00:25:20.317877
# 0 2020-05-18 10:25:37 2020-05-18 10:50:57.194877087 00:25:20.194877
# 2 2019-10-16 14:47:59 2019-10-16 15:04:38.566877853 00:16:39.566877
# 1 2020-06-17 16:12:41 2020-06-17 16:26:09.953120330 00:13:28.953120
# 0 2020-05-13 12:23:48 2020-05-13 12:34:27.255976810 00:10:39.255976
# 0 2020-05-18 15:37:19 2020-05-18 15:47:58.249976104 00:10:39.249976
# 1 2019-10-16 09:10:50 2019-10-16 09:19:07.946993819 00:08:17.946993
# 0 2020-05-18 14:05:40 2020-05-18 14:16:19.243975398 00:10:39.243975
# 0 2020-05-29 12:50:06 2020-05-29 13:15:25.184572835 00:25:19.184572
# 0 2020-06-04 13:03:15 2020-06-04 14:08:31.675403186 01:05:16.675403
# 0 2020-06-04 15:40:54 2020-06-04 16:03:57.837577608 00:23:03.837577
# 0 2020-06-04 10:38:11 2020-06-04 11:02:47.883538579 00:24:36.883538
# 2 2019-10-16 10:18:28 2019-10-16 10:43:47.335869216 00:25:19.335869
# 3 2019-10-16 13:04:40 2019-10-16 13:30:00.270875987 00:25:20.270875
# 0 2020-06-17 23:07:27 2020-06-17 23:34:25.702584883 00:26:58.702584
# 0 2020-06-17 18:02:47 2020-06-17 18:52:51.285157804 00:50:04.285157
# 0 2020-05-29 15:40:34 2020-05-29 16:03:02.160586351 00:22:28.160586
# 0 2020-06-17 21:02:56 2020-06-17 21:21:01.059218394 00:18:05.059218
#
#                                    individual Series  \
# 0          Name   SizeT          Start time      ...
# 1          Name   SizeT          Start time      ...
# 1          Name  SizeT          Start time       ...
# 0          Name  SizeT          Start time       ...
# 0          Name  SizeT          Start time       ...
# 0          Name   SizeT          Start time      ...
# 0          Name  SizeT          Start time       ...
# 0          Name   SizeT          Start time      ...
# 0          Name   SizeT          Start time      ...
# 2          Name  SizeT          Start time       ...
# 1          Name  SizeT          Start time       ...
# 0          Name  SizeT          Start time       ...
# 0          Name  SizeT          Start time       ...
# 1          Name  SizeT          Start time       ...
# 0          Name  SizeT          Start time       ...
# 0          Name  SizeT          Start time       ...
# 0          Name  SizeT          Start time       ...
# 0          Name  SizeT          Start time       ...
# 0          Name  SizeT          Start time       ...
# 2          Name   SizeT          Start time      ...
# 3          Name   SizeT          Start time      ...
# 0          Name  SizeT          Start time       ...
# 0          Name  SizeT          Start time       ...
# 0          Name  SizeT          Start time       ...
# 0          Name  SizeT          Start time       ...
#
#                                                    f  \
# 0  [0.0, 0.0006578125, 0.001315625, 0.0019734375,...
# 1  [0.0, 0.0006578125, 0.001315625, 0.0019734375,...
# 1  [0.0, 0.0013742690058479532, 0.002748538011695...
# 0  [0.0, 0.0008394160583941605, 0.001678832116788...
# 0  [0.0, 0.0015625, 0.003125, 0.00468750000000000...
# 0  [0.0, 0.0006570312500000001, 0.001314062500000...
# 0  [0.0, 0.001565625, 0.00313125, 0.004696875, 0....
# 0  [0.0, 0.0006578125, 0.001315625, 0.0019734375,...
# 0  [0.0, 0.0006578125, 0.001315625, 0.0019734375,...
# 2  [0.0, 0.0010005228385379533, 0.002001045677075...
# 1  [0.0, 0.00123625, 0.0024725, 0.00370875, 0.004...
# 0  [0.0, 0.001565625, 0.00313125, 0.004696875, 0....
# 0  [0.0, 0.001565625, 0.00313125, 0.004696875, 0....
# 1  [0.0, 0.0020040485829959515, 0.004008097165991...
# 0  [0.0, 0.001565625, 0.00313125, 0.004696875, 0....
# 0  [0.0, 0.000659121171770972, 0.0013182423435419...
# 0  [0.0, 0.0002552839646529895, 0.000510567929305...
# 0  [0.0, 0.0007236842105263158, 0.001447368421052...
# 0  [0.0, 0.0006775485063135201, 0.001355097012627...
# 2  [0.0, 0.0006578125, 0.001315625, 0.0019734375,...
# 3  [0.0, 0.0006578125, 0.001315625, 0.0019734375,...
# 0  [0.0, 0.00061875, 0.0012375, 0.001856250000000...
# 0  [0.0, 0.00033300784538199945, 0.00066601569076...
# 0  [0.0, 0.0007429364751791679, 0.001485872950358...
# 0  [0.0, 0.0009216417910447762, 0.001843283582089...
#
#                                                    p                exp
# 0  [(415432.36842105264+0j), (24481.798210530415-...  Experiment49b.lif
# 1  [(903305.3872919818+0j), (76732.37896787236-19...  Experiment39c.lif
# 1  [(31647.494371482175+0j), (-459.10252037366445...  ExperimentOGB.lif
# 0  [(42744.47772474145+0j), (79.28271477086312-11...  Experiment53b.lif
# 0  [(81340.7780511811+0j), (178.27744743520933-37...  Experiment50b.lif
# 0  [(455515.3851851852+0j), (-9146.852927356314-4...  Experiment50a.lif
# 0  [(28150.35644637053+0j), (-280.4986583308203-1...  Experiment49f.lif
# 0  [(609804.5604249667+0j), (8887.489035253904-49...  Experiment39f.lif
# 0  [(483354.7082728592+0j), (46939.68056771977-10...  Experiment49a.lif
# 2  [(818632.8293706292+0j), (15181.93088547999-92...  Experiment39e.lif
# 1  [(32307.92309859155+0j), (188.46397756523126-1...  Experiment53a.lif
# 0  [(33245.3465266559+0j), (128.30804811611105-20...  Experiment48b.lif
# 0  [(43761.79714030384+0j), (487.3787076127988-34...  Experiment49e.lif
# 1  [(57493.49683544303+0j), (17.768443611168895-4...  Experiment39a.lif
# 0  [(47186.58155016643+0j), (479.9031149575657-35...  Experiment49d.lif
# 0  [(112971.51814223512+0j), (-770.6429557409189-...  Experiment51a.lif
# 0  [(79843.6780137414+0j), (-344.29917607591716-9...  Experiment52b.lif
# 0  [(58791.077030812325+0j), (-1273.8726504412919...  Experiment52c.lif
# 0  [(300249.1875901876+0j), (-2923.7389466523414-...  Experiment52a.lif
# 2  [(356342.255499154+0j), (98757.57620057013-279...  Experiment39b.lif
# 3  [(884855.740276035+0j), (19258.607702212426-92...  Experiment39d.lif
# 0  [(87904.97471554995+0j), (-2771.9021032029027-...  Experiment53f.lif
# 0  [(84563.5993012631+0j), (864.1918438935262-413...  Experiment53c.lif
# 0  [(107777.72522522522+0j), (-3226.812950631381-...  Experiment51b.lif
# 0  [(28899.984968152865+0j), (-303.09176140523584...  Experiment53e.lif

# %%
plt.plot(*power_spectrum(x, fr=freq))
plt.ylim(0,1000)
# Out:
# (0, 1000)

# %%
pw
# Out:
# []

# %%
javabridge.kill_vm()

# %%
df = []
for cur,dirs,files in os.walk(folder):
    for file in files:
        if file.endswith('pkl'):
            path = os.path.join(cur,file)
            row = {"exp":path.split(".lif")[0].split("/")[-1],
                   "ser":os.path.split(cur)[-1],
                   "size":os.path.getsize(path)/1e6,
                   "path":path,
                  }
            imageFile = os.path.join(cur, ".image_"+file.replace("_rois.pkl",".png"))
            row["image"] = os.path.isfile(imageFile)
            df += [row]
#             print (path)
#             with open(path,'rb') as f:
#                 regions = pickle.load(f)
#             regions.update()
#             im = regions.image
#             figsize=np.array(im.shape)[::-1]/40
#             fig = plt.figure(figsize=figsize)
#             ax = fig.add_axes([0, 0, 1, 1])
#             regions.plotEdges(ax=ax,color="red")
#             fig.savefig(imageFile)
#             plt.close(fig)
#             toBreak = False
#     if toBreak: break

# %%
import pandas as pd

# %%
df = pd.DataFrame(df)

# %%
x = [ddf['size'].values for (exp,ser),ddf in df.groupby(["exp","ser"])]

# %%
from general_functions import tally

# %%
tally(map(len,x))
# Out:
# [(4, 87)]

# %%
x = np.array(x)

# %%
cv = x.std(1)/x.mean(1)
plt.hist(cv)
# Out:
# (array([14.,  2.,  2., 11., 26.,  9.,  6.,  7.,  6.,  4.]),
#  array([0.00658561, 0.02932093, 0.05205624, 0.07479156, 0.09752687,
#         0.12026218, 0.1429975 , 0.16573281, 0.18846813, 0.21120344,
#         0.23393875]),
#  <a list of 10 Patch objects>)

# %%
x[np.argmin(cv)]
# Out:
# array([11.850477, 11.858177, 11.667351, 11.760294])

# %%
(~df.image).any()
# Out:
# False
