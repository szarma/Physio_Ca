# %%
## importing stuff
import os
import pickle
from sys import path as syspath
syspath.append(os.path.expanduser("~/srdjan_functs/"))
import numpy as np
import matplotlib.pyplot as plt

# %config InlineBackend.figure_format = 'retina'
# %load_ext autoreload
# %autoreload 2
# %aimport islets

import pandas as pd

# from islets.Recording import Recording
from islets.Regions import Regions
from islets.numeric import power_spectrum, rebin
from islets.utils import show_movie
from islets.Regions import getPeak2BoundaryDF, getGraph_of_ROIs_to_Merge, mergeBasedOnGraph

from caiman import movie as cmovie

from matplotlib.colors import LogNorm
# Out:
# /opt/tljh/user/envs/physio/lib/python3.7/site-packages/sklearn/utils/deprecation.py:144: FutureWarning:
#
# The sklearn.decomposition.incremental_pca module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.decomposition. Anything that cannot be imported from sklearn.decomposition is now part of the private API.

# %%
# from caiman import load as cload

# %%
folder = "/data/Sandra/2020/TIM2020/"

# %%
for c,d,fs in os.walk(folder):
    for f in sorted(fs):
        if "tif" in f:
            print (c,f)
# Out:
# /data/Sandra/2020/TIM2020/ HeLa 2 high power large +++_nile red sted_scalebar.tif
# /data/Sandra/2020/TIM2020/ HeLa 2 high power large +++_nile red_scalebar.tif
# /data/Sandra/2020/TIM2020/fish_exocitosis fish 01 movie 300ms per frame GFP.tif
# /data/Sandra/2020/TIM2020/fish_exocitosis fish 01 movie 300ms per frame mCherry.tif
# /data/Sandra/2020/TIM2020/fish_exocitosis fish 02 movie 300ms per frame GFP.tif
# /data/Sandra/2020/TIM2020/fish_exocitosis fish 02 movie 300ms per frame mCherry.tif
# /data/Sandra/2020/TIM2020/fish_exocitosis fish 02 overview mCherry.tif

# %%
# from skimage import io
# im = io.imread(folder+"fish_exocitosis/fish 01 movie 300ms per frame GFP.tif", )
# im.shape

# %%
from PIL import Image, ImageSequence
im = Image.open(folder+"fish_exocitosis/fish 02 movie 300ms per frame GFP.tif")

movie = np.zeros((im.n_frames, )+im.size)

i = 0
for frame in ImageSequence.Iterator(im):
    movie[i] = np.array(frame).T
    i += 1
#     continue

# %%
show_movie(movie, NTimeFrames=len(movie),
#            tmax=len(movie)*.3
          )
# show_movie(np.transpose(movie,(1,0,2)), NTimeFrames=10)
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img81c99f30b4984a8ca474e302c1a64c55">
#   <div class="anim-controls">
#     <input id="_anim_slider81c99f30b4984a8ca474e302c1a64c55" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim81c99f30b4984a8ca474e302c1a64c55.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim81c99f30b4984a8ca474e302c1a64c55.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim81c99f30b4984a8ca474e302c1a64c55.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim81c99f30b4984a8ca474e302c1a64c55.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim81c99f30b4984a8ca474e302c1a64c55.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim81c99f30b4984a8ca474e302c1a64c55.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim81c99f30b4984a8ca474e302c1a64c55.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim81c99f30b4984a8ca474e302c1a64c55.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim81c99f30b4984a8ca474e302c1a64c55.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim81c99f30b4984a8ca474e302c1a64c55.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select81c99f30b4984a8ca474e302c1a64c55" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_81c99f30b4984a8ca474e302c1a64c55"
#              >
#       <label for="_anim_radio1_81c99f30b4984a8ca474e302c1a64c55">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_81c99f30b4984a8ca474e302c1a64c55"
#              checked>
#       <label for="_anim_radio2_81c99f30b4984a8ca474e302c1a64c55">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_81c99f30b4984a8ca474e302c1a64c55"
#              >
#       <label for="_anim_radio3_81c99f30b4984a8ca474e302c1a64c55">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img81c99f30b4984a8ca474e302c1a64c55";
#     var slider_id = "_anim_slider81c99f30b4984a8ca474e302c1a64c55";
#     var loop_select_id = "_anim_loop_select81c99f30b4984a8ca474e302c1a64c55";
#     var frames = new Array(200);
#
#   frames[0] = "...\
# AAAPYQAAD2EBqD+naQAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjIsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy8li6FKAAAa90lEQVRogd2a3U+b9/n/X+l832Df4Gc7NsQGbJ4d\
# SHhoM0jT0EVbtrZZ1amrtkVaqyrSpD1oB9vBDvoPbIerNKknO1qltT1It6bdUIIGWQMtCZBACYaA\
# ARuw4wds3+b2Db6d9ncQ+dNF/Qt+X0tIiIfbvj7Xdb2v9/t9fY49evToq729PRobGzl27Bj/v7++\
# +uorSqUSJBKJr4D/c1+mxsZGAH7961+TTCbp6Ojg4OCAcrmM1+vFMAy2trbw+/0EAgFisRgNDQ1I\
# ksTOzg4Au7u7RCIRMpkMbW1tbG5uksvlOHXqFA8fPuTEiRM8ePAAs9nMiRMn2NnZ4ZlnnuHWrVsA\
# HB4eYhgGPp8Pi8UCQCaTwePxkEgkqK+vR5IkDMNgcHCQqakpzp8/z+zsLCaTiXQ6TSaTQVEUOjo6\
# +Nvf/sZTtfJzu928+uqr2O12q

# %%
plt.imshow(movie.mean(0))

# %%
plt.imshow(movie.std(0))

# %%
movie = cmovie(np.array(im), fr=1./.3)

# %%
movie.shape
# Out:
# (50, 59)

# %%
plt.imshow(movie)

# %%
# from copy import deepcopy
fracSaturTh = .05
cmap = plt.cm.Greys
cmap.set_bad("lime")
pd.set_option('display.max_rows', 100)

# %%
# rec = Recording("/data/Sandra/2020/2020_06_24/Experiment56a.lif")
# rec = Recording("/data/MB2020_lifs/2012/2012_01_31/Pancreas_Islet_OGB13.lif")

# %%
# recs = [Recording("/data/Sandra/2020/2020_06_22/Series%03i.nd2"%i) for i in range(9,14)]

# for rec in recs:
#     display(rec.metadata)

# %%
rec = Recording("/data/Sandra/2020/2020_06_22/Series011.nd2")

# %%
ser = "all"

# %%
rec.import_series(ser)

# %%
metadata = rec.Series[ser]['metadata']

# %%
metadata
# Out:
# Name                                                               all
# SizeT                                                            18487
# SizeX                                                              256
# SizeY                                                              256
# pxSize                                                           0.829
# pxUnit                                                              µm
# bit depth                                                       uint16
# Frequency                                                           19
# Start time                                                         NaT
# End time                                                           NaT
# Duration                                        0 days 00:16:14.156120
# individual Series                           Name  SizeT Start time ...
# Name: 0, dtype: object

# %%
movie = cmovie(rec.Series[ser]['data'],fr = metadata.Frequency)

# %%
dmovie = np.diff(movie.astype(np.in16))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-cbd112800262> in <module>
# ----> 1 dmovie = np.diff(movie.astype(np.in16))
#
# AttributeError: module 'numpy' has no attribute 'in16'

# %%
plt.plot(dmovie.mean((1,2)))

# %%
movie.shape
# Out:
# (18487, 256, 256)

# %%
movie.fr
# Out:
# 19.0

# %%
meanImage = movie.mean(0)

# %%
plt.imshow(meanImage, norm=LogNorm())

# %%
Nsatur = (movie==movie.max()).sum(0)

# %%
plt.imshow(Nsatur.astype(float),
#            norm=LogNorm()
          )
plt.colorbar()

# %%
plt.rcParams["animation.embed_limit"] = 200

# %%
# saveMovie(movie, "embed")

# %% [markdown]
# ### Wiggles?

# %%
rwig = Regions(meanImage, gSig_filt=(3,))

# %%
freq = metadata["Frequency"]

# %%
n = 20
modFreq = []
for i in rwig.df.index:
    point = rwig.df.loc[i,"peak"]
    x = movie[:,point[0],point[1]]
    f,p = power_spectrum(x, fr=freq)
    f,p = f[f>1],np.abs(p[f>1])
    f = rebin(f,n)
    p = rebin(p,n)
    rwig.df.loc[i,"peakFreq"] = f[np.argmax(p)]
    rwig.df.loc[i,"peakProminence"] = np.max(p)

# %%
tmpdf = rwig.df[["peakValue","peakFreq","peakProminence"]].copy()
tmpdf["log10 mean"] = np.log10(tmpdf["peakValue"])
tmpdf["log10 peakProminence"] = np.log10(tmpdf["peakProminence"])
del tmpdf["peakProminence"], tmpdf["peakValue"]
pd.plotting.scatter_matrix(tmpdf, figsize=(10,10));

# %% [markdown]
# ### import pickle

# %%
sorted(os.listdir(os.path.join(rec.path+"_analysis",ser)))
# Out:
# ['.image_7.10.png',
#  '.image_7.8.png',
#  '.image_7.png',
#  '.image_8.png',
#  '7.10_rois.pkl',
#  '7.8_rois.pkl',
#  '7_rois.pkl',
#  '8_rois.pkl',
#  'Series011.nd2_all.mp4']

# %%
pickleFile = os.path.join(rec.path+"_analysis",ser,"8_rois.pkl")
with open(pickleFile,"rb") as f:
    regions = pickle.load(f)

# %%
regions.update()
regions.detrend_traces()
# Out:
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# invalid value encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# invalid value encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# invalid value encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# invalid value encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# divide by zero encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# invalid value encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# invalid value encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# invalid value encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# invalid value encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# invalid value encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# invalid value encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# divide by zero encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# divide by zero encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# divide by zero encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# divide by zero encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# divide by zero encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# divide by zero encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# divide by zero encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# divide by zero encountered in log
#
# /home/jupyter-srdjan/srdjan_functs/islets/numeric.py:122: RuntimeWarning:
#
# divide by zero encountered in log

# %%
regions.plotEdges()

# %%
regions.infer_gain(plot=True)

# %%
regions.gain
# Out:
# 82.33755353054417

# %%
movie.shape, movie.dtype, movie.max()
# Out:
# ((18487, 256, 256), dtype('uint16'), movie(4095, dtype=uint16))

# %%
# saveMovie(movie[:1000], "embed")

# %%
from islets.numeric import get_sep_th

# %%
intTh = np.exp(get_sep_th(np.log(regions.df.interest), plot=True))

# %%
# show_movie(movie,
#            NTimeFrames=180,
#            additionalPlot=lambda ax_:regions.plotEdges(ax=ax_, image=False, color="navy",ix)
#           )

# %%
plt.plot(regions.df.trace[0])
