# %%
import logging
# reload(logging)
logger = logging.getLogger(__name__)

logging.basicConfig(format='%(asctime)s %(levelname)s:%(message)s', level=logging.INFO)

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import scipy.signal as signal

# %%
# %matplotlib notebook

# %%
from sys import path as syspath
syspath.append("/Users/marjanslakrupnik/Downloads/Physio_Ca-master/functions/")

# %%
from physio_def_1 import *

# %%
# %config Completer.use_jedi = True

# %%
import collective

# %%
matplotlib.rcParams['mathtext.fontset'] = 'custom'
matplotlib.rcParams['mathtext.rm'] = 'Bitstream Vera Sans'
matplotlib.rcParams['mathtext.it'] = 'Bitstream Vera Sans:italic'
matplotlib.rcParams['mathtext.bf'] = 'Bitstream Vera Sans:bold'

# %%
allData = np.load('/Users/marjanslakrupnik/Downloads/Experiment38c_Series009.npy')

# %%
allData.shape
# Out:
# (128000, 128, 128)

# %%
roiWidth = 7
NRois = 100
RoiOrigins = np.array([
    np.random.randint(allData.shape[1]-roiWidth,size=NRois),
    np.random.randint(allData.shape[2]-roiWidth,size=NRois)
]).T

# %%
# # if you have retina display:
# %config InlineBackend.figure_format = 'retina'

# %%
# plt.figure(figsize=(10,10))
ax = plt.subplot(111)
plt.imshow(allData[:100].mean(0))
addRoisToImage(RoiOrigins,roiWidth,ax=ax,label=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
RoiOrigins[0]
# Out:
# array([44, 67])

# %%
roiProfiles = getRoiProfiles(RoiOrigins,roiWidth,image_=allData)

# %%
ts = np.vstack(list(roiProfiles.values()))
# eemd = np.load('its0.npy')
pos = RoiOrigins+roiWidth/2
ncells = len(ts)

# %%
x = ts[84]

# %%
plt.plot(x)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
N  = 2
Wn = 0.001
B, A = signal.butter(N, Wn, output='ba')
tsf_low = signal.filtfilt(B,A, x)
plt.plot(tsf_low)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
N  = 2
Wn = 0.1
B, A = signal.butter(N, Wn, output='ba')
tsf_high = signal.filtfilt(B,A, x)
plt.plot(tsf_high)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
signal.filtfilt?

# %%
fig, axs = plt.subplots(2,1,figsize=(9,5), sharex=True)
wSlight = 1./20
wIron   = 1./2000
ironedx         = signal.filtfilt(*signal.butter(2, wIron,   output='ba'), x=x)
axs[0].plot(x,lw=.3,alpha = .2)
axs[0].plot(ironedx)

slightFilteredx = signal.filtfilt(*signal.butter(2, wSlight, output='ba'), x=x-ironedx)

axs[1].plot(x-ironedx,lw=.3)
axs[1].plot(slightFilteredx,lw=.7)

axs[0].set_xlim(0,30000)
fig.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="900">

# %%
i
# Out:
# 0

# %%
(ts[i]==x).all()
# Out:
# True

# %%
detrendedRois = np.zeros_like(ts)

# %%
# %%time
for i in range(1):
    x = ts[i]
    slightFilteredx = signal.filtfilt(B,A, x)
    ironedx = signal.medfilt(x,[2001],)
    detrendedRois[i] = slightFilteredx-ironedx
# Out:
# CPU times: user 14.1 s, sys: 49.4 ms, total: 14.1 s
# Wall time: 14.1 s

# %%
# %%time
# slightFilteredx = signal.filtfilt(B,A, x)
ironedx = signal.medfilt(x,[2001],)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# /usr/local/anaconda3/lib/python3.7/site-packages/scipy/signal/signaltools.py in medfilt(volume, kernel_size)
#     925     numels = prod(kernel_size, axis=0)
#     926     order = numels // 2
# --> 927     return sigtools._order_filterND(volume, domain, order)
#     928
#     929
#
# KeyboardInterrupt:

# %%
ax = plt.subplot(111)
plt.imshow(detrended)
ax.set_aspect("auto")

# %%
y = tsf_high-tsf_low
y_scaled = (y-min(y))/(max(y)-min(y))
plt.plot(y_scaled)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
xeemd = eemd[110]
eemd_scaled = (xeemd-min(xeemd))/(max(xeemd)-min(xeemd))
plt.plot(eemd_scaled)

# %%
bin = 20
spins = []
for k in xrange(len(ts)):
    x = ts[k]
    N  = 2
    Wn = 0.005
    B, A = signal.butter(N, Wn, output='ba')
    tsf_low = signal.filtfilt(B,A, x)
    N  = 2
    Wn = 0.2
    B, A = signal.butter(N, Wn, output='ba')
    tsf_high = signal.filtfilt(B,A, x)
    y = tsf_high-tsf_low
    y_scaled = (y-min(y))/(max(y)-min(y))
    n = len(y_scaled)
    s = np.empty(n//bin)
    s.fill(-1)
    y_cutoff = np.mean(y_scaled[:4000])
    y_std = np.std(y_scaled[:4000])
    for i in xrange(0,n-bin,bin):
        if np.mean(y_scaled[i:i+bin]) > y_cutoff+3*y_std:
            s[i//bin] = 1
    spins.append(s)
    
# firing rate
fr = [(sum(spins[k])/len(spins[k])+1)/2/bin for k in xrange(len(spins))]
inz = np.where(np.array(fr) > 0.0)[0]
nzfr = [fr[k] for k in inz]
s = [spins[i] for i in inz]
numspikes = [sum(spins[k]+1) for k in xrange(len(spins))]
idx = np.where(np.array(numspikes) >= 15.0)[0]
s = [spins[i] for i in idx]
pos = [pos[i] for i in idx]

# %%
plt.plot(spins[110])

# %%
cm = np.cov(s)
cv = []
for i in xrange(len(cm)):
	for j in xrange(i+1,len(cm)):
		cv.append(cm[i,j])

# %%
_,_,_ = plt.hist(cv, bins=50,normed=1,color='white')

# %%
d = []
crds = []
n = len(pos)
for i in xrange(n):
	for j in xrange(i+1,n):
		d.append(np.sqrt((pos[i][0]-pos[j][0])**2+(pos[i][1]-pos[j][1])**2))
		crds.append([i,j])

# %%
dd = 10.0
cav = []
dav = []
cstd = []
counts = []
corr = cv
for c in np.linspace(min(d),max(d)-dd,int((max(d)-dd-min(d))/dd)):
	idx = np.where((np.array(d) < c+dd) & (np.array(d) > c))[0]
	counts.append(len(idx))
	cav.append(np.mean([corr[i] for i in idx]))
	dav.append(np.mean([d[i] for i in idx]))
	cstd.append(np.std([corr[i] for i in idx]))

# %%
pixel_length = 317.32/256
plt.plot(pixel_length*np.array(d[::10]),corr[::10],ls='',marker='.',mfc='none',lw=1.5,mew=1.5,ms=8,color='lightgray')
plt.plot(pixel_length*np.array(dav),cav,ls='--',marker='+',lw=1.0,color='black',ms=12)
#plt.plot(dav,var/np.max(var),ls='--',marker='.',lw=1.0,color='black',ms=11)
plt.xlabel('cell-cell distance, um',fontsize=16)
plt.ylabel('correlations',fontsize=16)
